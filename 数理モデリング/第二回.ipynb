# %% [markdown]
# <a href="https://colab.research.google.com/github/Akamurasaki1/Univ/blob/main/%E6%95%B0%E7%90%86%E3%83%A2%E3%83%87%E3%83%AA%E3%83%B3%E3%82%B0/%E7%AC%AC%E4%BA%8C%E5%9B%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **演習1** \
# 丸め誤差の回避
#
# ```
# format(x,’.20f’)
# ```
# は小数点以下20 桁
# で表示するために指定している。 \

# %%
x=0.1
print(format(x,'.20f'))
# Out:
# 0.10000000000000000555

# %% [markdown]
# 次にこのx = 0.1 をN 回足した結果を表示するプログラムを作ろう。N を大きな数として（例
# えばN = 1000000）実行して結果を見てみよう。また理論値と得られた計算値の違いを考えよう

# %%
N=1000000
print(x*N)
y=0
for i in range(N):
  y+=x
print(y)
# Out:
# 100000.0
# 100000.00000133288

# %% [markdown]
# （発展）丸め誤差はDecimal モジュールcを使うことで回避できる．調べて実装してみよう．

# %% [markdown]
# 演習4: ロジスティック写像のコンピュータ実験（１）\
# 1.（準備）NumPy 配列ndarray を使うと便利なので慣れよう。下のプログラム例2 を打ち込んで
# みて，その挙動を確かめよ． \
# 2. ロジスティック写像(10) のパラメタをµ = 0.9、初期値をx0 = 0.1 としてn = 100 まで計算
# して縦軸をxn、横軸をn として折れ線グラフを描いてみよう。 \
#
# 3. 初期値x0 を色々変えて計算してみよう。 \
# 4. µ = 0.9 の場合，時間が十分経過するとどのような状態になると言えそうか（つまり lim
# xn）？

# %%
import numpy as np

x=np.array([0,1,2])
print(x)
print(x[0])
print(x[1])

x=np.zeros(3)
print(x)
# Out:
# [0 1 2]
# 0
# 1
# [0. 0. 0.]

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =0.9
N=100
x=np.zeros(N+1)
x[0]=0.1

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =1.2
N=100
x=np.zeros(N+1)
x[0]=0.1

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =1.11111111112
N=100
x=np.zeros(N+1)
x[0]=0.1

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =0.9
N=100
x=np.zeros(N+1)
x[0]=2.5

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()
# Out:
# <ipython-input-28-9e136a2f0bbf>:9: RuntimeWarning: overflow encountered in scalar multiply
#   x[i+1]=mu*x[i]*(1-x[i])

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =1.1111111111111
N=100
x=np.zeros(N+1)
x[0]=0.1

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =1.11111111111112
N=100
x=np.zeros(N+1)
x[0]=0.1

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =1.11111111111111111111111
N=100
x=np.zeros(N+1)
x[0]=0.1

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
mu =3.4
N=100
x=np.zeros(N+1)
x[0]=0.1

for i in range(N):
  x[i+1]=mu*x[i]*(1-x[i])
plt.plot(x,'-o')
plt.show()
